# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("/content/BlackFridaySales.csv")

# Convert the "Purchase" column to numeric
data['Purchase'] = pd.to_numeric(data['Purchase'], errors='coerce')

# Drop rows with missing Purchase values
data.dropna(subset=['Purchase'], inplace=True)

# Continue with your analysis...

sns.distplot(data["Purchase"], color='r')
plt.title("Purchase Distribution")
plt.show()

sns.boxplot(data["Purchase"])
plt.title("Boxplot of Purchase")
plt.show()

print("Skewness:", data["Purchase"].skew())
print("Kurtosis:", data["Purchase"].kurtosis())
print("Description:\n", data["Purchase"].describe())

sns.countplot(data['Gender'])
plt.show()

print("Percentage of Gender Distribution:")
print(data['Gender'].value_counts(normalize=True) * 100)

# Convert "Purchase" column back to numeric for calculations
data['Purchase'] = pd.to_numeric(data['Purchase'])

# Mean Purchase by Gender
mean_purchase_by_gender = data.groupby("Gender")["Purchase"].mean()
print("Mean Purchase by Gender:")
print(mean_purchase_by_gender)

# Continue with the rest of your analysis...
print(data['Marital_Status'].dtype)
print(data['Marital_Status'].unique())
mean_purchase_by_gender = data.groupby("Gender")["Purchase"].mean()
print("Mean Purchase by Gender:")
print(mean_purchase_by_gender)
# Check the unique values of 'Marital_Status' again
print(data['Marital_Status'].unique())
# Plot count plot for 'Marital_Status'
sns.countplot(data['Marital_Status'])
plt.title("Marital Status Distribution")
plt.show()
# Out:
# <ipython-input-11-e0710fe93df2>:16: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Purchase"], color='r')
# Skewness: 0.6480342388811218
# Kurtosis: -0.2777816860312501
# Description:
#  count    23086.000000
# mean      9238.940224
# std       4931.808224
# min        186.000000
# 25%       5846.000000
# 50%       8044.000000
# 75%      11990.000000
# max      23958.000000
# Name: Purchase, dtype: float64
# Percentage of Gender Distribution:
# Gender
# M    75.829507
# F    24.170493
# Name: proportion, dtype: float64
# Mean Purchase by Gender:
# Gender
# F    8733.189606
# M    9400.147150
# ...

# %%
print("Percentage of Gender Distribution:")
print(data['Gender'].value_counts(normalize=True) * 100)
# Out:
# Percentage of Gender Distribution:
# Gender
# M    75.829507
# F    24.170493
# Name: proportion, dtype: float64

# %%
# Convert "Purchase" column back to numeric for calculations
data['Purchase'] = data['Purchase'].astype(float)

# %%
# Mean Purchase by Gender
mean_purchase_by_gender = data.groupby("Gender")["Purchase"].mean()
print("Mean Purchase by Gender:")
print(mean_purchase_by_gender)
plt.figure(figsize=(18,5))
sns.countplot(data['Occupation'])
plt.show()
# Out:
# Mean Purchase by Gender:
# Gender
# F    8733.189606
# M    9400.147150
# Name: Purchase, dtype: float64

# %%
# Convert the "Purchase" column to numeric, coercing errors
data['Purchase'] = pd.to_numeric(data['Purchase'], errors='coerce')

# Drop rows with missing Purchase values
data.dropna(subset=['Purchase'], inplace=True)

# Group by 'Occupation' and calculate the mean of 'Purchase'
occup = pd.DataFrame(data.groupby("Occupation")["Purchase"].mean())

# Plot the bar chart
occup.plot(kind='bar', figsize=(15, 5))
plt.title("Occupation and Purchase Analysis")
plt.xlabel("Occupation")
plt.ylabel("Mean Purchase")
plt.show()

# %%
sns.countplot(data['City_Category'])
plt.show()

# %%
# Convert the "Purchase" column to numeric, coercing errors
data['Purchase'] = pd.to_numeric(data['Purchase'], errors='coerce')

# Drop rows with missing Purchase values
data.dropna(subset=['Purchase'], inplace=True)

# Group by 'City_Category' and calculate the mean of 'Purchase'
city_purchase_mean = data.groupby("City_Category")["Purchase"].mean()

# Plot the bar chart
city_purchase_mean.plot(kind='bar')
plt.title("City Category and Purchase Analysis")
plt.xlabel("City Category")
plt.ylabel("Mean Purchase")
plt.show()

# %%
sns.countplot(data['Stay_In_Current_City_Years'])
plt.show()

# %%
# Convert the "Purchase" column to numeric, coercing errors
data['Purchase'] = pd.to_numeric(data['Purchase'], errors='coerce')

# Drop rows with missing Purchase values
data.dropna(subset=['Purchase'], inplace=True)

# Group by 'Stay_In_Current_City_Years' and calculate the mean of 'Purchase'
stay_purchase_mean = data.groupby("Stay_In_Current_City_Years")["Purchase"].mean()

# Plot the bar chart
stay_purchase_mean.plot(kind='bar')
plt.title("Stay_In_Current_City_Years and Purchase Analysis")
plt.xlabel("Stay In Current City Years")
plt.ylabel("Mean Purchase")
plt.show()

# %%
sns.countplot(data['Age'])
plt.title('Distribution of Age')
plt.xlabel('Different Categories of Age')
plt.show()

# %%
# Convert the "Purchase" column to numeric, coercing errors
data['Purchase'] = pd.to_numeric(data['Purchase'], errors='coerce')

# Drop rows with missing Purchase values
data.dropna(subset=['Purchase'], inplace=True)

# Group by 'Age' and calculate the mean of 'Purchase'
age_purchase_mean = data.groupby("Age")["Purchase"].mean()

# Plot the bar chart for mean purchase by age
age_purchase_mean.plot(kind='bar')
plt.title("Mean Purchase by Age")
plt.xlabel("Age")
plt.ylabel("Mean Purchase")
plt.show()

# Alternatively, if you want to plot the sum of purchases by age, you can use:
# Group by 'Age' and calculate the sum of 'Purchase'
age_purchase_sum = data.groupby("Age")["Purchase"].sum()

# Plot the bar chart for sum of purchases by age
age_purchase_sum.plot(kind='bar')
plt.title("Total Purchase Amount by Age")
plt.xlabel("Age")
plt.ylabel("Total Purchase Amount")
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Product_Category_1'])
plt.show()

# %%
# Convert the "Purchase" column to numeric, coercing errors
data['Purchase'] = pd.to_numeric(data['Purchase'], errors='coerce')

# Drop rows with missing Purchase values
data.dropna(subset=['Purchase'], inplace=True)

# Group by 'Product_Category_1' and calculate the mean of 'Purchase'
product_category_1_purchase_mean = data.groupby('Product_Category_1')["Purchase"].mean()

# Plot the bar chart
product_category_1_purchase_mean.plot(kind='bar', figsize=(18, 5))
plt.title("Product_Category_1 and Purchase Mean Analysis")
plt.xlabel("Product Category 1")
plt.ylabel("Mean Purchase")
plt.show()

# %%
data.groupby('Product_Category_1').sum()['Purchase'].plot(kind='bar',figsize=(18,5))
plt.title("Product_Category_1 and Purchase Analysis")
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Product_Category_2'])
plt.show()

# %%
plt.figure(figsize=(18,5))
sns.countplot(data['Product_Category_3'])
plt.show()

# %%
# Convert all columns to numeric, coercing errors
data = data.apply(pd.to_numeric, errors='coerce')

# Drop rows with missing values
data.dropna(inplace=True)

# Calculate the correlation matrix
correlation_matrix = data.corr()

# Plot the heatmap of the correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True)
plt.title("Correlation Matrix")
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# /usr/local/lib/python3.10/dist-packages/seaborn/matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %%
data.columns
df = data.copy()

# %%
# Assuming 'Stay_In_Current_City_Years' column exists in the DataFrame 'df'

# Check if 'Stay_In_Current_City_Years' column exists in 'df'
if 'Stay_In_Current_City_Years' in df.columns:
    # Convert categorical variables into dummy/indicator variables
    df = pd.get_dummies(df, columns=['Stay_In_Current_City_Years'])

    # Drop rows with missing values
    df.dropna(inplace=True)

    # Convert 'Gender', 'Age', and 'City_Category' columns to numeric using LabelEncoder
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    df['Gender'] = le.fit_transform(df['Gender'])
    df['Age'] = le.fit_transform(df['Age'])
    df['City_Category'] = le.fit_transform(df['City_Category'])

    # Convert 'Product_Category_2' and 'Product_Category_3' columns to integer and fill missing values with 0
    df['Product_Category_2'] = df['Product_Category_2'].fillna(0).astype(int)
    df['Product_Category_3'] = df['Product_Category_3'].fillna(0).astype(int)

    # Check for any remaining missing values
    df.isnull().sum()

    # Split the data into features (X) and target variable (y)
    X = df.drop(["User_ID", "Product_ID", "Purchase"], axis=1)
    y = df['Purchase']

    # Split the data into training and testing sets
    from sklearn.model_selection import train_test_split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=123)

    # Continue with your modeling code...
else:
    print("'Stay_In_Current_City_Years' column does not exist in the DataFrame.")
# Out:
# 'Stay_In_Current_City_Years' column does not exist in the DataFrame.
